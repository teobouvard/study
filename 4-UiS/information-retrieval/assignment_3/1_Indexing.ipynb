# %% [markdown]
# # Assignment 3, Indexing
#
# In this notebook you will index DBpedia (see the sub-collections listed under `https://github.com/uis-dat640-fall2019/admin/tree/master/assignments/assignment-3#data`).
#
# Make sure you specify the index settings, analyzer, and fields appropriately for to support the models to be implemented in subsequent notebooks.
#
# Note: you'll need to build a positional index. Use a single shard to make sure you're getting the right term statistics.
#
# Be sure to use both markdown cells with section headings and explanations, as well as writing readable code, to make it clear what your intention is each step of the way through the code.

# %%
# fix jupyter notebook narrow style
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import os
import subprocess
import json

from pprint import pprint
from tqdm import tqdm
from elasticsearch import Elasticsearch
from elasticsearch import helpers
from elasticsearch import RequestError
# Out:
# <style>.container { width:100% !important; }</style>

# %%
def get_n_lines(filename):
    return int(subprocess.check_output(['wc', '-l', filename]).decode('utf8').split()[0])

# %% [markdown]
# # Initialize Elasticsearch index

# %%
es = Elasticsearch()
es.info()
# Out:
# {'name': 'HoG',
#  'cluster_name': 'elasticsearch',
#  'cluster_uuid': 'Zle62SN2R0-CJz5T3d07Og',
#  'version': {'number': '7.4.2',
#   'build_flavor': 'default',
#   'build_type': 'deb',
#   'build_hash': '2f90bbf7b93631e52bafb59b3b049cb44ec25e96',
#   'build_date': '2019-10-28T20:40:44.881551Z',
#   'build_snapshot': False,
#   'lucene_version': '8.2.0',
#   'minimum_wire_compatibility_version': '6.8.0',
#   'minimum_index_compatibility_version': '6.0.0-beta1'},
#  'tagline': 'You Know, for Search'}

# %%
INDEX_NAME = 'collection_v2'

INDEX_SETTINGS = {
    'settings' : {
        'index' : {
            "number_of_shards" : 1,
            "number_of_replicas" : 0
        },
        'analysis': {
            'analyzer': {
                'english_analyzer': {
                    'type': "custom",
                    'tokenizer': "standard",
                    'filter': [
                        "lowercase",
                        "asciifolding",
                        "dbpedia_stop",
                        "english_stop",
                        "stemming_english_minimal"
                    ]                
                },
            },
            'filter' : {
                'stemming_english_minimal' : {
                    'type': "stemmer",
                    'name': "minimal_english"
                },
                'english_stop': {
                    'type': "stop",
                    'stopwords': "_english_"
                },
                'dbpedia_stop': {
                    'type': "stop",
                    'stopwords': ["en", "http", "www", "org"]
                }
            },
        }
    },
    'mappings': {
        'properties': {
            'names': {
                'type': "text",
                'term_vector': "with_positions",
                'analyzer': "english_analyzer"
            },
            'categories': {
                'type': "text",
                'term_vector': "with_positions",
                'analyzer': "english_analyzer"
            },
            'similar_entity_names': {
                'type': "text",
                'term_vector': "with_positions",
                'analyzer': "english_analyzer"
            },
            'attributes': {
                'type': "text",
                'term_vector': "with_positions",
                'analyzer': "english_analyzer"
            },
            'related_entity_names': {
                'type': "text",
                'term_vector': "with_positions",
                'analyzer': "english_analyzer"
            },
            'related_entity_uri': {
                'type': "text",
                'analyzer': "whitespace"
            },
           'catch_all': {
                'type': "text",
                'term_vector': "with_positions",
                'analyzer': "english_analyzer"
            }
        }
    }
}

# %%
es.indices.get_alias('*')
#es.indices.delete(index=INDEX_NAME)   
#es.indices.create(index=INDEX_NAME, body=INDEX_SETTINGS)

# %% [markdown]
# # Files used

# %%
# filename, reverse relations
files = {
    'knowledge_base/anchor_text_en.ttl' : False,
    'knowledge_base/article_categories_en.ttl' : False,
    'knowledge_base/disambiguations_en.ttl' : True,
    'knowledge_base/infobox_properties_en.ttl' : False,
    'knowledge_base/instance_types_transitive_en.ttl' : False,
    'knowledge_base/labels_en.ttl' : False,
    'knowledge_base/long_abstracts_en.ttl' : False,
    'knowledge_base/mappingbased_literals_en.ttl' : False,
    'knowledge_base/mappingbased_objects_en.ttl' : False,
    'knowledge_base/page_links_en.ttl' : False,
    'knowledge_base/persondata_en.ttl' : False,
    'knowledge_base/short_abstracts_en.ttl' : False,
    'knowledge_base/transitive_redirects_en.ttl' : True,
}

# %% [markdown]
# ## Fields predicates

# %%
fields = {
    'names' : [
        '<http://xmlns.com/foaf/0.1/name>',
        '<http://dbpedia.org/property/name>',
        '<http://xmlns.com/foaf/0.1/givenName>',
        '<http://xmlns.com/foaf/0.1/surname>',
        '<http://dbpedia.org/property/officialName>',
        '<http://dbpedia.org/property/officialNames>',
        '<http://dbpedia.org/property/fullName>',
        '<http://dbpedia.org/property/nativename>',
        '<http://dbpedia.org/property/birthname>',
        '<http://dbpedia.org/property/nickname>',
        '<http://dbpedia.org/property/nicknames>',
        '<http://dbpedia.org/property/showName>',
        '<http://dbpedia.org/property/shipName>',
        '<http://dbpedia.org/property/clubname>',
        '<http://dbpedia.org/property/unitName>',
        '<http://dbpedia.org/property/otherNames>',
        '<http://dbpedia.org/property/othernames>',
        '<http://dbpedia.org/property/otherName>',
        '<http://dbpedia.org/property/othername>',
        '<http://dbpedia.org/property/formerNames>',
        '<http://dbpedia.org/property/formerName>',
        '<http://dbpedia.org/property/formernames>',
        '<http://dbpedia.org/property/birthName>',
        '<http://dbpedia.org/property/birthname>',
        '<http://dbpedia.org/property/alternativeNames>',
        '<http://dbpedia.org/property/alternateNames>',
        '<http://dbpedia.org/property/otherNames>',
        '<http://dbpedia.org/property/othernames>',
        '<http://dbpedia.org/property/names>',
        '<http://dbpedia.org/property/fullname>',
        '<http://www.w3.org/2000/01/rdf-schema#label>'
    ],
    'categories' : [
        '<http://purl.org/dc/terms/subject>'
    ],
    'similar_entity_names' : [
        '<http://dbpedia.org/ontology/wikiPageWikiLinkText>',
        '<http://dbpedia.org/ontology/wikiPageDisambiguates>',
        '<http://dbpedia.org/ontology/wikiPageRedirects>'
    ]
}

# %% [markdown]
# ## Load entity, category and property labels

# %%
def read_ttl(filename, predicate_match):
    mapping = {}
 
    with open(filename, 'r') as f:
        for line in tqdm(f, desc=f'extracting {filename}', total=get_n_lines(filename)):
            if not line.startswith('<'):
                continue

            line = line.split(' ', maxsplit=2)
            subject, predicate, object = line[0], line[1], line[2]
            if predicate == predicate_match and subject not in mapping:
                mapping[subject] = object
                
    return mapping

# %%
predicate_match = '<http://www.w3.org/2000/01/rdf-schema#label>'

filename = 'knowledge_base/labels_en.ttl'
entity_labels = read_ttl(filename, predicate_match)

filename = 'knowledge_base/category_labels_en.ttl'
category_labels = read_ttl(filename, predicate_match)

filename = 'knowledge_base/infobox_property_definitions_en.ttl'
property_labels = read_ttl(filename, predicate_match)

# %% [markdown]
# ## URI resolution

# %%
def is_literal(x):
    return True if x.endswith('@en .\n') or x.endswith('".\n') else False

def is_attribute(x):
    return True if x.startswith('<http://dbp') else False

def is_category(x):
    return True if x.startswith('<http://dbpedia.org/resource/Category:') else False

def resolve_category(x):
    return category_labels.get(x, x)

def is_property(x):
    return True if x.startswith('<http://dbpedia.org/property/') else False

def resolve_property(x):
    # what to put as default value ? ex : <http://www.w3.org/2000/01/rdf-schema#comment> is not resolved ?
    return property_labels.get(x, x)

def is_entity(x):
    return True if x.startswith('<http://dbpedia.org/resource/') else False

def resolve_entity(x):
    return entity_labels.get(x, x)

def is_http(x):
    return True if x.startswith('<http') else False

def resolve_http(x):
    return x.split('>')[0].split('/')[-1]

def is_typed(x):
    return True if '^^<' in x else False

def resolve_type(x):
    return x.split('"^^')[0]

def resolve(x):
    if is_category(x):
        return resolve_category(x)
    elif is_property(x):
        return resolve_property(x)
    elif is_entity(x):
        return resolve_entity(x)
    elif is_http(x):
        return resolve_http(x)
    elif is_typed(x):
        return resolve_type(x)
    else:
        return x

# %% [markdown]
# ## Entity serialization

# %%
def serialize_entity(entity, predicates, objects):
    entry = {
        'names' : '',
        'categories' : '',
        'similar_entity_names' : '',
        'attributes' : '',
        'related_entity_names' : '',
        'related_entity_uri' : '',
        'catch_all' : ''
    }
    
    for pred, obj in zip(predicates, objects):
        resolved_obj = resolve(obj)
        resolved_pred = resolve(pred)
        
        found_field = False
        for field, predicate_list in fields.items():
            if pred in predicate_list:
                entry[field] =  f'{entry[field]} {resolved_obj}'
                found_field = True
                break
        
        if not found_field:
            if is_attribute(pred) and is_literal(obj):
                    entry['attributes'] = f'{entry["attributes"]} {resolved_pred} {resolved_obj}'
            elif is_attribute(pred) and is_entity(obj):
                    entry['related_entity_names'] = f'{entry["related_entity_names"]} {resolved_obj}'
                    entry['related_entity_uri'] = f'{entry["related_entity_uri"]} {obj}'
            else:
                entry['catch_all'] = f'{entry["catch_all"]} {resolved_obj}'
            
    return entry

# %% [markdown]
# ## Memory indexing

# %%
def merge_with_collection(entity, entry, collection):
    if entity not in collection:
        collection[entity] = entry
    else:
        for key, value in entry.items():
            collection[entity][key] = ' '.join([value, collection[entity][key]])

# %%
def generate_data(collection):
    for entity, entry in tqdm(collection.items(), desc=f'indexing collection'):
        if len(bytes(entity, 'utf-8')) < 512 and entry['names'].strip() and entry['catch_all'].strip():
            yield {
                '_index': INDEX_NAME,
                '_id' : entity,
                '_source': entry,
            }

# %%
collection = {}

# %%
def index_collection():
    for filename, reverse_relation in files.items():
        
        current_subject = None
        predicates = []
        objects = []
        
        with open(filename,'r') as f:
            for i, line in enumerate(tqdm(f, desc=f'reading {filename}', total=get_n_lines(filename))):
                if not line.startswith('<'):
                    continue

                line = line.split(' ', maxsplit=2)
                
                if reverse_relation:
                    subject, predicate, object = line[2], line[1], line[0]
                    # get rid of the trailing characters at the end of the line
                    subject = subject.split(' ')[0]
                else:
                    subject, predicate, object = line[0], line[1], line[2]
                    # to properly retrieve entity URI
                    if not is_literal(object):
                        object = object.split(' ')[0]

                # on first line, initialize current subject
                if current_subject is None:
                    current_subject = subject

                # while subject is the same, add predicates and objects to subject
                if subject == current_subject:
                    predicates.append(predicate)
                    objects.append(object)

                # when subject changes, merge entity with collection in memory
                else:
                    entry = serialize_entity(current_subject, predicates, objects)
                    merge_with_collection(current_subject, entry, collection)
                    current_subject = subject
                    predicates = [predicate]
                    objects = [object]

# %%
index_collection()

# %% [markdown]
# ## Elasticsearch indexing

# %%
# finally, index collection
helpers.bulk(es, generate_data(collection))

# %% [markdown]
# ## Testing our index

# %%
pprint(es.search(index=INDEX_NAME, q='encryption standard', filter_path=['hits.hits._id']))
# Out:
# {'hits': {'hits': [{'_id': '<http://dbpedia.org/resource/Advanced_Encryption_Standard>'},
#                    {'_id': '<http://dbpedia.org/resource/Data_Encryption_Standard>'},
#                    {'_id': '<http://dbpedia.org/resource/Advanced_Encryption_Standard_process>'},
#                    {'_id': '<http://dbpedia.org/resource/S-63_(encryption_standard)>'},
#                    {'_id': '<http://dbpedia.org/resource/AES_implementations>'},
#                    {'_id': '<http://dbpedia.org/resource/Intel_Cascade_Cipher>'},
#                    {'_id': '<http://dbpedia.org/resource/IEEE_P1619>'},
#                    {'_id': '<http://dbpedia.org/resource/AES_instruction_set>'},
#                    {'_id': '<http://dbpedia.org/resource/Brute_Force:_Cracking_the_Data_Encryption_Standard>'},
#                    {'_id': '<http://dbpedia.org/resource/Poly1305>'}]}}

# %%
doc = es.get(index=INDEX_NAME, id='<http://dbpedia.org/resource/Advanced_Encryption_Standard>')
pprint(doc)
# Out:
# {'_id': '<http://dbpedia.org/resource/Advanced_Encryption_Standard>',
#  '_index': 'collection_v2',
#  '_primary_term': 1,
#  '_seq_no': 39548,
#  '_source': {'attributes': '                        abstract "The Advanced '
#                            'Encryption Standard (AES), also known as Rijndael '
#                            '(its original name), is a specification for the '
#                            'encryption of electronic data established by the '
#                            'U.S. National Institute of Standards and '
#                            'Technology (NIST) in 2001.AES is based on the '
#                            'Rijndael cipher developed by two Belgian '
#                            'cryptographers, Joan Daemen and Vincent Rijmen, '
#                            'who submitted a proposal to NIST during the AES '
#                            'selection process. Rijndael is a family of ciphers '
#                            'with different key and block sizes.For AES, NIST '
#                            'selected three members of the Rijndael family, '
#                            'each with a block size of 128 bits, but three '
#                            'different key lengths: 128, 192 and 256 bits.AES '
#                            'has been adopted by the U.S. government and is now '
#                            'used worldwide. It supersedes the Data Encryption '
#                            'Standard (DES), which was published in 1977. The '
#                            'algorithm described by AES is a symmetric-key '
#                            'algorithm, meaning the same key is used for both '
#                            'encrypting and decrypting the data.In the United '
#                            'States, AES was announced by the NIST as U.S. FIPS '
#                            'PUB 197 (FIPS 197) on November 26, 2001. This '
#                            'announcement followed a five-year standardization '
#                            'process in which fifteen competing designs were '
#                            'presented and evaluated, before the Rijndael '
#                            'cipher was selected as the most suitable (see '
#                            'Advanced Encryption Standard process for more '
#                            'details).AES became effective as a federal '
#                            'government standard on May 26, 2002 after approval '
#                            'by the Secretary of Commerce. AES is included in '
#                            'the ISO/IEC 18033-3 standard. AES is available in '
#                            'many different encryption packages, and is the '
#                            'first publicly accessible and open cipher approved '
#                            'by the National Security Agency (NSA) for top '
#                            'secret information when used in an NSA approved '
#                            'cryptographic module (see Security of AES, '
#                            'below).The name Rijndael (Dutch pronunciation: '
#                            '[ˈrɛindaːl]) is a play on the names of the two '
#                            'inventors (Joan Daemen and Vincent Rijmen). It is '
#                            'also a combination of the Dutch name for the Rhine '
#                            'river and a dale."@en .\n'
#                            '   "Caption"@en .\n'
#                            ' "The SubBytes step, one of four stages in a round '
#                            'of AES"@en .\n'
#                            ' "certification"@en .\n'
#                            ' "AES winner, CRYPTREC, NESSIE, NSA"@en .\n'
#                            ' "cryptanalysis"@en .\n'
#                            ' "Attacks have been published that are '
#                            'computationally faster than a full brute force '
#                            'attack, though none as of 2013 are computationally '
#                            'feasible.\\n\\nFor AES-128, the key can be '
#                            'recovered with a computational complexity of '
#                            '2126.1 using the biclique attack. For biclique '
#                            'attacks on AES-192 and AES-256, the computational '
#                            'complexities of 2189.7 and 2254.4 respectively '
#                            'apply. Related-key attacks can break AES-192 and '
#                            'AES-256 with complexities 2176 and 299.5, '
#                            'respectively."@en .\n'
#                            '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ',
#              'catch_all': '                      "The Advanced Encryption '
#                           'Standard (AES), also known as Rijndael (its '
#                           'original name), is a specification for the '
#                           'encryption of electronic data established by the '
#                           'U.S. National Institute of Standards and Technology '
#                           '(NIST) in 2001.AES is based on the Rijndael cipher '
#                           'developed by two Belgian cryptographers, Joan '
#                           'Daemen and Vincent Rijmen, who submitted a proposal '
#                           'to NIST during the AES selection process."@en .\n'
#                           '     "1998 "128192 "128 '
#                           '"1012                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ',
#              'categories': '                            "Advanced Encryption '
#                            'Standard"@en .\n'
#                            '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ',
#              'names': '                         "Advanced Encryption '
#                       'Standard"@en .\n'
#                       '  "Advanced Encryption Standard"@en .\n'
#                       '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ',
#              'related_entity_names': '                       '
#                                      '<http://dbpedia.org/resource/File:AES-SubBytes.svg> '
#                                      '"Vincent Rijmen"@en .\n'
#                                      ' "Joan Daemen"@en .\n'
#                                      ' "Square (cipher)"@en .\n'
#                                      ' "Anubis (cipher)"@en .\n'
#                                      ' "Grand Cru (cipher)"@en .\n'
#                                      ' "Advanced Encryption Standard '
#                                      'process"@en .\n'
#                                      ' "CRYPTREC"@en .\n'
#                                      ' "NESSIE"@en .\n'
#                                      ' "National Security Agency"@en .\n'
#                                      ' "Substitution-permutation network"@en '
#                                      '.\n'
#                                      ' "Brute-force attack"@en .\n'
#                                      ' "Biclique attack"@en .\n'
#                                      ' "Related-key attack"@en .\n'
#                                      ' "Encryption"@en .\n'
#                                      ' "National Institute of Standards and '
#                                      'Technology"@en .\n'
#                                      ' "Cipher"@en .\n'
#                                      ' "Belgium"@en .\n'
#                                      ' "Federal government of the United '
#                                      'States"@en .\n'
#                                      ' "Data Encryption Standard"@en .\n'
#                                      ' "Symmetric-key algorithm"@en .\n'
#                                      ' "United States"@en .\n'
#                                      ' "Federal Information Processing '
#                                      'Standards"@en .\n'
#                                      ' "United States Secretary of '
#                                      'Commerce"@en .\n'
#                                      ' "Classified information"@en .\n'
#                                      ' "Advanced Encryption Standard"@en .\n'
#                                      ' "Rhine"@en .\n'
#                                      ' "Dale (landform)"@en .\n'
#                                      ' "Feistel cipher"@en .\n'
#                                      ' "Block size (cryptography)"@en .\n'
#                                      ' "Bit"@en .\n'
#                                      ' "Key size"@en .\n'
#                                      ' "Row-major order"@en .\n'
#                                      ' "Finite field arithmetic"@en .\n'
#                                      ' "Rijndael key schedule"@en .\n'
#                                      ' "Rijndael S-box"@en .\n'
#                                      ' "S-box"@en .\n'
#                                      ' "Multiplicative inverse"@en .\n'
#                                      ' "Finite field"@en .\n'
#                                      ' "Affine transformation"@en .\n'
#                                      ' "Derangement"@en .\n'
#                                      ' '
#                                      '<http://dbpedia.org/resource/File:AES-ShiftRows.svg> '
#                                      '"Offset (computer science)"@en .\n'
#                                      ' '
#                                      '<http://dbpedia.org/resource/File:AES-MixColumns.svg> '
#                                      '"Linear map"@en .\n'
#                                      ' "Confusion and diffusion"@en .\n'
#                                      ' "Exclusive or"@en .\n'
#                                      ' "Hexadecimal"@en .\n'
#                                      ' "MDS matrix"@en .\n'
#                                      ' "Rijndael mix columns"@en .\n'
#                                      ' '
#                                      '<http://dbpedia.org/resource/File:AES-AddRoundKey.svg> '
#                                      '"Key (cryptography)"@en .\n'
#                                      ' "Side-channel attack"@en .\n'
#                                      ' "Cryptanalysis"@en .\n'
#                                      ' "Brute-force attack"@en .\n'
#                                      ' "RC5"@en .\n'
#                                      ' "Distributed.net"@en .\n'
#                                      ' "XSL attack"@en .\n'
#                                      ' "Nicolas Courtois"@en .\n'
#                                      ' "Josef Pieprzyk"@en .\n'
#                                      ' "Bruce Schneier"@en .\n'
#                                      ' "Twofish"@en .\n'
#                                      ' "Alex Biryukov"@en .\n'
#                                      ' "Adi Shamir"@en .\n'
#                                      ' "Distinguishing attack"@en .\n'
#                                      ' "Key-recovery attack"@en .\n'
#                                      ' "Edward Snowden"@en .\n'
#                                      ' "Kendall rank correlation '
#                                      'coefficient"@en .\n'
#                                      ' "Side-channel attack"@en .\n'
#                                      ' "Daniel J. Bernstein"@en .\n'
#                                      ' "OpenSSL"@en .\n'
#                                      ' "Differential fault analysis"@en .\n'
#                                      ' "Cryptographic Module Validation '
#                                      'Program"@en .\n'
#                                      ' "Communications Security '
#                                      'Establishment"@en .\n'
#                                      ' "FIPS 140-2"@en .\n'
#                                      ' "FIPS 140"@en .\n'
#                                      ' "Triple DES"@en .\n'
#                                      ' "SHA-1"@en .\n'
#                                      ' "National Institute of Standards and '
#                                      'Technology"@en .\n'
#                                      ' "Smart card"@en .\n'
#                                      ' "Pentium Pro"@en .\n'
#                                      ' "Pentium M"@en .\n'
#                                      ' "Intel Core"@en .\n'
#                                      ' "List of Intel Core i5 '
#                                      'microprocessors"@en .\n'
#                                      ' "Intel Core"@en .\n'
#                                      ' "AMD Accelerated Processing Unit"@en .\n'
#                                      ' "AMD FX"@en .\n'
#                                      ' "AES instruction set"@en .\n'
#                                      ' "Disk encryption"@en .\n'
#                                      ' "Whirlpool (cryptography)"@en .\n'
#                                      ' "Asiacrypt"@en .\n'
#                                      ' "Portable Document Format"@en .\n'
#                                      ' "Advanced Encryption Standard"@en .\n'
#                                      '    "Vincent Rijmen"@en .\n'
#                                      ' "Joan Daemen"@en .\n'
#                                      ' "Square (cipher)"@en .\n'
#                                      ' "Anubis (cipher)"@en .\n'
#                                      ' "Grand Cru (cipher)"@en .\n'
#                                      ' "Substitution-permutation network"@en '
#                                      '.\n'
#                                      '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ',
#              'related_entity_uri': '                       '
#                                    '<http://dbpedia.org/resource/File:AES-SubBytes.svg> '
#                                    '<http://dbpedia.org/resource/Vincent_Rijmen> '
#                                    '<http://dbpedia.org/resource/Joan_Daemen> '
#                                    '<http://dbpedia.org/resource/Square_(cipher)> '
#                                    '<http://dbpedia.org/resource/Anubis_(cipher)> '
#                                    '<http://dbpedia.org/resource/Grand_Cru_(cipher)> '
#                                    '<http://dbpedia.org/resource/Advanced_Encryption_Standard_process> '
#                                    '<http://dbpedia.org/resource/CRYPTREC> '
#                                    '<http://dbpedia.org/resource/NESSIE> '
#                                    '<http://dbpedia.org/resource/National_Security_Agency> '
#                                    '<http://dbpedia.org/resource/Substitution-permutation_network> '
#                                    '<http://dbpedia.org/resource/Brute-force_attack> '
#                                    '<http://dbpedia.org/resource/Biclique_attack> '
#                                    '<http://dbpedia.org/resource/Related-key_attack> '
#                                    '<http://dbpedia.org/resource/Encryption> '
#                                    '<http://dbpedia.org/resource/National_Institute_of_Standards_and_Technology> '
#                                    '<http://dbpedia.org/resource/Cipher> '
#                                    '<http://dbpedia.org/resource/Belgium> '
#                                    '<http://dbpedia.org/resource/Federal_government_of_the_United_States> '
#                                    '<http://dbpedia.org/resource/Data_Encryption_Standard> '
#                                    '<http://dbpedia.org/resource/Symmetric-key_algorithm> '
#                                    '<http://dbpedia.org/resource/United_States> '
#                                    '<http://dbpedia.org/resource/Federal_Information_Processing_Standards> '
#                                    '<http://dbpedia.org/resource/United_States_Secretary_of_Commerce> '
#                                    '<http://dbpedia.org/resource/Classified_information> '
#                                    '<http://dbpedia.org/resource/Advanced_Encryption_Standard> '
#                                    '<http://dbpedia.org/resource/Rhine> '
#                                    '<http://dbpedia.org/resource/Dale_(landform)> '
#                                    '<http://dbpedia.org/resource/Feistel_cipher> '
#                                    '<http://dbpedia.org/resource/Block_size_(cryptography)> '
#                                    '<http://dbpedia.org/resource/Bit> '
#                                    '<http://dbpedia.org/resource/Key_size> '
#                                    '<http://dbpedia.org/resource/Row-major_order> '
#                                    '<http://dbpedia.org/resource/Finite_field_arithmetic> '
#                                    '<http://dbpedia.org/resource/Rijndael_key_schedule> '
#                                    '<http://dbpedia.org/resource/Rijndael_S-box> '
#                                    '<http://dbpedia.org/resource/S-box> '
#                                    '<http://dbpedia.org/resource/Multiplicative_inverse> '
#                                    '<http://dbpedia.org/resource/Finite_field> '
#                                    '<http://dbpedia.org/resource/Affine_transformation> '
#                                    '<http://dbpedia.org/resource/Derangement> '
#                                    '<http://dbpedia.org/resource/File:AES-ShiftRows.svg> '
#                                    '<http://dbpedia.org/resource/Offset_(computer_science)> '
#                                    '<http://dbpedia.org/resource/File:AES-MixColumns.svg> '
#                                    '<http://dbpedia.org/resource/Linear_map> '
#                                    '<http://dbpedia.org/resource/Confusion_and_diffusion> '
#                                    '<http://dbpedia.org/resource/Exclusive_or> '
#                                    '<http://dbpedia.org/resource/Hexadecimal> '
#                                    '<http://dbpedia.org/resource/MDS_matrix> '
#                                    '<http://dbpedia.org/resource/Rijndael_mix_columns> '
#                                    '<http://dbpedia.org/resource/File:AES-AddRoundKey.svg> '
#                                    '<http://dbpedia.org/resource/Key_(cryptography)> '
#                                    '<http://dbpedia.org/resource/Side-channel_attack> '
#                                    '<http://dbpedia.org/resource/Cryptanalysis> '
#                                    '<http://dbpedia.org/resource/Brute-force_attack> '
#                                    '<http://dbpedia.org/resource/RC5> '
#                                    '<http://dbpedia.org/resource/Distributed.net> '
#                                    '<http://dbpedia.org/resource/XSL_attack> '
#                                    '<http://dbpedia.org/resource/Nicolas_Courtois> '
#                                    '<http://dbpedia.org/resource/Josef_Pieprzyk> '
#                                    '<http://dbpedia.org/resource/Bruce_Schneier> '
#                                    '<http://dbpedia.org/resource/Twofish> '
#                                    '<http://dbpedia.org/resource/Alex_Biryukov> '
#                                    '<http://dbpedia.org/resource/Adi_Shamir> '
#                                    '<http://dbpedia.org/resource/Distinguishing_attack> '
#                                    '<http://dbpedia.org/resource/Key-recovery_attack> '
#                                    '<http://dbpedia.org/resource/Edward_Snowden> '
#                                    '<http://dbpedia.org/resource/Kendall_rank_correlation_coefficient> '
#                                    '<http://dbpedia.org/resource/Side-channel_attack> '
#                                    '<http://dbpedia.org/resource/Daniel_J._Bernstein> '
#                                    '<http://dbpedia.org/resource/OpenSSL> '
#                                    '<http://dbpedia.org/resource/Differential_fault_analysis> '
#                                    '<http://dbpedia.org/resource/Cryptographic_Module_Validation_Program> '
#                                    '<http://dbpedia.org/resource/Communications_Security_Establishment> '
#                                    '<http://dbpedia.org/resource/FIPS_140-2> '
#                                    '<http://dbpedia.org/resource/FIPS_140> '
#                                    '<http://dbpedia.org/resource/Triple_DES> '
#                                    '<http://dbpedia.org/resource/SHA-1> '
#                                    '<http://dbpedia.org/resource/National_Institute_of_Standards_and_Technology> '
#                                    '<http://dbpedia.org/resource/Smart_card> '
#                                    '<http://dbpedia.org/resource/Pentium_Pro> '
#                                    '<http://dbpedia.org/resource/Pentium_M> '
#                                    '<http://dbpedia.org/resource/Intel_Core> '
#                                    '<http://dbpedia.org/resource/List_of_Intel_Core_i5_microprocessors> '
#                                    '<http://dbpedia.org/resource/Intel_Core> '
#                                    '<http://dbpedia.org/resource/AMD_Accelerated_Processing_Unit> '
#                                    '<http://dbpedia.org/resource/AMD_FX> '
#                                    '<http://dbpedia.org/resource/AES_instruction_set> '
#                                    '<http://dbpedia.org/resource/Disk_encryption> '
#                                    '<http://dbpedia.org/resource/Whirlpool_(cryptography)> '
#                                    '<http://dbpedia.org/resource/Asiacrypt> '
#                                    '<http://dbpedia.org/resource/Portable_Document_Format> '
#                                    '<http://dbpedia.org/resource/Category:Advanced_Encryption_Standard>    '
#                                    '<http://dbpedia.org/resource/Vincent_Rijmen> '
#                                    '<http://dbpedia.org/resource/Joan_Daemen> '
#                                    '<http://dbpedia.org/resource/Square_(cipher)> '
#                                    '<http://dbpedia.org/resource/Anubis_(cipher)> '
#                                    '<http://dbpedia.org/resource/Grand_Cru_(cipher)> '
#                                    '<http://dbpedia.org/resource/Substitution-permutation_network>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ',
#              'similar_entity_names': ' "Rijndael cipher"@en .\n'
#                                      '  "AES cipher"@en .\n'
#                                      '  "Advanced Encryption System"@en .\n'
#                                      '  "Rijndael"@en .\n'
#                                      '  "AES Key"@en .\n'
#                                      '  "Advanced Encryption Technology"@en .\n'
#                                      '  "AES-192"@en .\n'
#                                      ' "AES192"@en .\n'
#                                      ' "Aes192"@en .\n'
#                                      ' "Aes-192"@en .\n'
#                                      '  "AES 192"@en .\n'
#                                      ' "AES 256"@en .\n'
#                                      '  "AES 128"@en .\n'
#                                      '  "Aes 256"@en .\n'
#                                      ' "Aes 192"@en .\n'
#                                      ' "Aes 128"@en .\n'
#                                      '  "AES256"@en .\n'
#                                      '  "Aes256"@en .\n'
#                                      '  "Aes128"@en .\n'
#                                      '  "Aes-128"@en .\n'
#                                      ' "AES-128"@en .\n'
#                                      ' "Aes-256"@en .\n'
#                                      ' "AES128"@en .\n'
#                                      '  "Rjindael"@en .\n'
#                                      '  "AES (cipher)"@en .\n'
#                                      '  "AES encryption"@en .\n'
#                                      '  "AES-256"@en .\n'
#                                      '  "FIPS 197"@en .\n'
#                                      '  "Rijndael algorithm"@en .\n'
#                                      '  "Rijndael encryption algorithm"@en .\n'
#                                      '       "AES"@en .\n'
#                                      '   "256-bit AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "256-bit AES encryption"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      ' "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "advanced encryption standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES-128-CB"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES-256"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "aes"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard '
#                                      '(AES)"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "256-bit AES encryption"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES encryption"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES128"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES-128"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES-256 encryption"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES128"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard '
#                                      '(AES)-256"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES encryption"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES encryption"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Rijndael/AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES-256 encryption"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES 256"@en .\n'
#                                      '  "AES-256"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      ' "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      ' "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      ' "Advanced Encryption Standard"@en .\n'
#                                      ' "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      ' "Advanced Encryption Standard"@en .\n'
#                                      ' "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      ' "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      ' "Advanced Encryption Standard"@en .\n'
#                                      ' "Advanced Encryption Standard"@en .\n'
#                                      ' "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES-256 bit"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES128/AES256"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced_Encryption_Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES-256"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES cipher"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES-256"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES 128"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard '
#                                      '(AES)"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Rijndael"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES-128"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES encryption"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "related-key attacks against AES"@en '
#                                      '.\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES-128"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "encryption"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES/Rijndael"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES (Rijndael)"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Rijndael/AES"@en .\n'
#                                      '  "AES encryption"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard '
#                                      '(AES)"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES-128, AES-192, AES-256"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Advanced Encryption Standard"@en .\n'
#                                      '  "AES"@en .\n'
#                                      '  "Security of AES"@en .\n'},
#  '_type': '_doc',
#  '_version': 1,
#  'found': True}

# %%
tv = es.termvectors(index=INDEX_NAME, id='<http://dbpedia.org/resource/Isaac_Asimov>', fields='*', field_statistics=True)['term_vectors']
pprint(tv)
# Out:
# {'attributes': {'field_statistics': {'doc_count': 4673761,
#                                      'sum_doc_freq': 285985189,
#                                      'sum_ttf': 408590200},
#                 'terms': {'10': {'term_freq': 1, 'tokens': [{'position': 88}]},
#                           '1920': {'term_freq': 1,
#                                    'tokens': [{'position': 32}]},
#                           '1948': {'term_freq': 1,
#                                    'tokens': [{'position': 485}]},
#                           '1964': {'term_freq': 1,
#                                    'tokens': [{'position': 219}]},
#                           '1965': {'term_freq': 1,
#                                    'tokens': [{'position': 421}]},
#                           '1992': {'term_freq': 1,
#                                    'tokens': [{'position': 35}]},
#                           '2': {'term_freq': 1, 'tokens': [{'position': 31}]},
#                           '500': {'term_freq': 1, 'tokens': [{'position': 70}]},
#                           '5020': {'term_freq': 1,
#                                    'tokens': [{'position': 394}]},
#                           '54491': {'term_freq': 1,
#                                     'tokens': [{'position': 512}]},
#                           '6': {'term_freq': 1, 'tokens': [{'position': 34}]},
#                           '9': {'term_freq': 1, 'tokens': [{'position': 85}]},
#                           '90,000': {'term_freq': 1,
#                                      'tokens': [{'position': 75}]},
#                           'about': {'term_freq': 1,
#                                     'tokens': [{'position': 377}]},
#                           'abstract': {'term_freq': 1,
#                                        'tokens': [{'position': 20}]},
#                           'aggressive': {'term_freq': 1,
#                                          'tokens': [{'position': 376}]},
#                           'albeit': {'term_freq': 1,
#                                      'tokens': [{'position': 363}]},
#                           'alia': {'term_freq': 1, 'tokens': [{'position': 5}]},
#                           'all': {'term_freq': 1,
#                                   'tokens': [{'position': 236}]},
#                           'along': {'term_freq': 1,
#                                     'tokens': [{'position': 101}]},
#                           'also': {'term_freq': 1,
#                                    'tokens': [{'position': 255}]},
#                           'america': {'term_freq': 1,
#                                       'tokens': [{'position': 228}]},
#                           'american': {'term_freq': 4,
#                                        'tokens': [{'position': 38},
#                                                   {'position': 389},
#                                                   {'position': 454},
#                                                   {'position': 519}]},
#                           'anderson': {'term_freq': 1,
#                                        'tokens': [{'position': 204}]},
#                           'april': {'term_freq': 1,
#                                     'tokens': [{'position': 33}]},
#                           'arthur': {'term_freq': 1,
#                                      'tokens': [{'position': 107}]},
#                           'asimov': {'term_freq': 9,
#                                      'tokens': [{'position': 22},
#                                                 {'position': 61},
#                                                 {'position': 238},
#                                                 {'position': 395},
#                                                 {'position': 419},
#                                                 {'position': 435},
#                                                 {'position': 441},
#                                                 {'position': 501},
#                                                 {'position': 506}]},
#                           "asimov'": {'term_freq': 2,
#                                       'tokens': [{'position': 124},
#                                                  {'position': 333}]},
#                           'association': {'term_freq': 1,
#                                           'tokens': [{'position': 391}]},
#                           'asteroid': {'term_freq': 1,
#                                        'tokens': [{'position': 393}]},
#                           'astronomy': {'term_freq': 1,
#                                         'tokens': [{'position': 344}]},
#                           'author': {'term_freq': 1,
#                                      'tokens': [{'position': 39}]},
#                           'award': {'term_freq': 1,
#                                     'tokens': [{'position': 409}]},
#                           'back': {'term_freq': 1,
#                                    'tokens': [{'position': 281}]},
#                           'been': {'term_freq': 1,
#                                    'tokens': [{'position': 82}]},
#                           'beginning': {'term_freq': 1,
#                                         'tokens': [{'position': 165}]},
#                           'being': {'term_freq': 1,
#                                     'tokens': [{'position': 385}]},
#                           'best': {'term_freq': 2,
#                                    'tokens': [{'position': 47},
#                                               {'position': 230}]},
#                           'big': {'term_freq': 1,
#                                   'tokens': [{'position': 116}]},
#                           'biochemist': {'term_freq': 1,
#                                          'tokens': [{'position': 522}]},
#                           'biochemistry': {'term_freq': 3,
#                                            'tokens': [{'position': 43},
#                                                       {'position': 461},
#                                                       {'position': 484}]},
#                           'birth': {'term_freq': 3,
#                                     'tokens': [{'position': 301},
#                                                {'position': 423},
#                                                {'position': 526}]},
#                           'birthname': {'term_freq': 1,
#                                         'tokens': [{'position': 0}]},
#                           'blugerman': {'term_freq': 1,
#                                         'tokens': [{'position': 430}]},
#                           'book': {'term_freq': 4,
#                                    'tokens': [{'position': 60},
#                                               {'position': 71},
#                                               {'position': 80},
#                                               {'position': 270}]},
#                           'born': {'term_freq': 2,
#                                    'tokens': [{'position': 25},
#                                               {'position': 518}]},
#                           'boston': {'term_freq': 1,
#                                      'tokens': [{'position': 45}]},
#                           'brain': {'term_freq': 1,
#                                     'tokens': [{'position': 373}]},
#                           'brooklyn': {'term_freq': 2,
#                                        'tokens': [{'position': 403},
#                                                   {'position': 446}]},
#                           'c': {'term_freq': 1, 'tokens': [{'position': 108}]},
#                           'caption': {'term_freq': 1,
#                                       'tokens': [{'position': 416}]},
#                           'category': {'term_freq': 1,
#                                        'tokens': [{'position': 90}]},
#                           'chemistry.asimov': {'term_freq': 1,
#                                                'tokens': [{'position': 351}]},
#                           'children': {'term_freq': 2,
#                                        'tokens': [{'position': 432},
#                                                   {'position': 437}]},
#                           'chronology': {'term_freq': 1,
#                                          'tokens': [{'position': 334}]},
#                           'circa': {'term_freq': 1,
#                                     'tokens': [{'position': 29}]},
#                           'clarke': {'term_freq': 1,
#                                      'tokens': [{'position': 109}]},
#                           'classification.asimov': {'term_freq': 1,
#                                                     'tokens': [{'position': 95}]},
#                           'columbia': {'term_freq': 1,
#                                        'tokens': [{'position': 481}]},
#                           'concept': {'term_freq': 1,
#                                       'tokens': [{'position': 273}]},
#                           'considered': {'term_freq': 1,
#                                          'tokens': [{'position': 112}]},
#                           'cordwainer': {'term_freq': 1,
#                                          'tokens': [{'position': 200}]},
#                           'crater': {'term_freq': 1,
#                                      'tokens': [{'position': 397}]},
#                           'creating': {'term_freq': 1,
#                                        'tokens': [{'position': 180}]},
#                           'criticism': {'term_freq': 1,
#                                         'tokens': [{'position': 477}]},
#                           'dale': {'term_freq': 1,
#                                    'tokens': [{'position': 15}]},
#                           'date': {'term_freq': 2,
#                                    'tokens': [{'position': 302},
#                                               {'position': 305}]},
#                           'david': {'term_freq': 1,
#                                     'tokens': [{'position': 434}]},
#                           'death': {'term_freq': 3,
#                                     'tokens': [{'position': 304},
#                                                {'position': 443},
#                                                {'position': 537}]},
#                           'debut': {'term_freq': 1,
#                                     'tokens': [{'position': 487}]},
#                           'decimal': {'term_freq': 1,
#                                       'tokens': [{'position': 94}]},
#                           'described': {'term_freq': 1,
#                                         'tokens': [{'position': 366}]},
#                           'description': {'term_freq': 1,
#                                           'tokens': [{'position': 515}]},
#                           'dewey': {'term_freq': 1,
#                                     'tokens': [{'position': 93}]},
#                           'discovery': {'term_freq': 1,
#                                         'tokens': [{'position': 338}]},
#                           'distant': {'term_freq': 1,
#                                       'tokens': [{'position': 172}]},
#                           'during': {'term_freq': 1,
#                                      'tokens': [{'position': 121}]},
#                           'e': {'term_freq': 1, 'tokens': [{'position': 17}]},
#                           'earlier': {'term_freq': 1,
#                                       'tokens': [{'position': 153}]},
#                           'edge': {'term_freq': 1,
#                                    'tokens': [{'position': 168}]},
#                           'edited': {'term_freq': 1,
#                                      'tokens': [{'position': 67}]},
#                           'education': {'term_freq': 1,
#                                         'tokens': [{'position': 479}]},
#                           'elementary': {'term_freq': 1,
#                                          'tokens': [{'position': 404}]},
#                           'empire': {'term_freq': 2,
#                                      'tokens': [{'position': 139},
#                                                 {'position': 147}]},
#                           'essay': {'term_freq': 1,
#                                     'tokens': [{'position': 475}]},
#                           'estimated': {'term_freq': 1,
#                                         'tokens': [{'position': 74}]},
#                           'etymology': {'term_freq': 1,
#                                         'tokens': [{'position': 314}]},
#                           'example': {'term_freq': 1,
#                                       'tokens': [{'position': 321}]},
#                           'explain': {'term_freq': 1,
#                                       'tokens': [{'position': 271}]},
#                           'explicitly': {'term_freq': 1,
#                                          'tokens': [{'position': 150}]},
#                           'famous': {'term_freq': 1,
#                                      'tokens': [{'position': 126}]},
#                           'fantasy': {'term_freq': 1,
#                                       'tokens': [{'position': 259}]},
#                           'far': {'term_freq': 1,
#                                   'tokens': [{'position': 280}]},
#                           'federative': {'term_freq': 1,
#                                          'tokens': [{'position': 531}]},
#                           'fiction': {'term_freq': 8,
#                                       'tokens': [{'position': 54},
#                                                  {'position': 99},
#                                                  {'position': 119},
#                                                  {'position': 215},
#                                                  {'position': 225},
#                                                  {'position': 233},
#                                                  {'position': 247},
#                                                  {'position': 466}]},
#                           'fictional': {'term_freq': 1,
#                                         'tokens': [{'position': 158}]},
#                           'foundation': {'term_freq': 2,
#                                          'tokens': [{'position': 130},
#                                                     {'position': 162}]},
#                           "foundation'": {'term_freq': 1,
#                                           'tokens': [{'position': 167}]},
#                           'french': {'term_freq': 1,
#                                      'tokens': [{'position': 12}]},
#                           'french.asimov': {'term_freq': 1,
#                                             'tokens': [{'position': 254}]},
#                           'future': {'term_freq': 2,
#                                      'tokens': [{'position': 173},
#                                                 {'position': 183}]},
#                           'galactic': {'term_freq': 2,
#                                        'tokens': [{'position': 138},
#                                                   {'position': 146}]},
#                           'genre': {'term_freq': 1,
#                                     'tokens': [{'position': 463}]},
#                           'george': {'term_freq': 1,
#                                      'tokens': [{'position': 16}]},
#                           'gertrude': {'term_freq': 1,
#                                        'tokens': [{'position': 429}]},
#                           'going': {'term_freq': 1,
#                                     'tokens': [{'position': 278}]},
#                           'gov.archives.arc': {'term_freq': 1,
#                                                'tokens': [{'position': 511}]},
#                           'guide': {'term_freq': 2,
#                                     'tokens': [{'position': 317},
#                                                {'position': 323}]},
#                           'hard': {'term_freq': 1,
#                                    'tokens': [{'position': 97}]},
#                           'have': {'term_freq': 1,
#                                    'tokens': [{'position': 81}]},
#                           'he': {'term_freq': 7,
#                                  'tokens': [{'position': 110},
#                                             {'position': 169},
#                                             {'position': 205},
#                                             {'position': 297},
#                                             {'position': 309},
#                                             {'position': 365},
#                                             {'position': 380}]},
#                           'heinlein': {'term_freq': 2,
#                                        'tokens': [{'position': 105},
#                                                   {'position': 195}]},
#                           'hi': {'term_freq': 8,
#                                  'tokens': [{'position': 50},
#                                             {'position': 57},
#                                             {'position': 79},
#                                             {'position': 122},
#                                             {'position': 132},
#                                             {'position': 186},
#                                             {'position': 267},
#                                             {'position': 413}]},
#                           'historical': {'term_freq': 1,
#                                          'tokens': [{'position': 276}]},
#                           'history': {'term_freq': 3,
#                                       'tokens': [{'position': 154},
#                                                  {'position': 184},
#                                                  {'position': 346}]},
#                           'honor': {'term_freq': 1,
#                                     'tokens': [{'position': 414}]},
#                           'humanist': {'term_freq': 1,
#                                        'tokens': [{'position': 390}]},
#                           'hundred': {'term_freq': 1,
#                                       'tokens': [{'position': 207}]},
#                           'id': {'term_freq': 2,
#                                  'tokens': [{'position': 504},
#                                             {'position': 509}]},
#                           'include': {'term_freq': 1,
#                                       'tokens': [{'position': 322}]},
#                           'including': {'term_freq': 1,
#                                         'tokens': [{'position': 211}]},
#                           'international': {'term_freq': 1,
#                                             'tokens': [{'position': 362}]},
#                           'iq': {'term_freq': 1, 'tokens': [{'position': 379}]},
#                           'isaac': {'term_freq': 4,
#                                     'tokens': [{'position': 21},
#                                                {'position': 418},
#                                                {'position': 500},
#                                                {'position': 507}]},
#                           'isaak': {'term_freq': 2,
#                                     'tokens': [{'position': 1},
#                                                {'position': 26}]},
#                           'it': {'term_freq': 1, 'tokens': [{'position': 294}]},
#                           'january': {'term_freq': 1,
#                                       'tokens': [{'position': 30}]},
#                           'joan': {'term_freq': 1,
#                                    'tokens': [{'position': 440}]},
#                           'joy': {'term_freq': 1,
#                                   'tokens': [{'position': 383}]},
#                           'juvenile': {'term_freq': 1,
#                                        'tokens': [{'position': 245}]},
#                           'known': {'term_freq': 1,
#                                     'tokens': [{'position': 48}]},
#                           'later': {'term_freq': 1,
#                                     'tokens': [{'position': 164}]},
#                           'letter': {'term_freq': 1,
#                                      'tokens': [{'position': 76}]},
#                           'lifetime': {'term_freq': 1,
#                                        'tokens': [{'position': 123}]},
#                           'like': {'term_freq': 1,
#                                    'tokens': [{'position': 189}]},
#                           'linked': {'term_freq': 1,
#                                      'tokens': [{'position': 170}]},
#                           'literary': {'term_freq': 2,
#                                        'tokens': [{'position': 408},
#                                                   {'position': 476}]},
#                           'long': {'term_freq': 1,
#                                    'tokens': [{'position': 354}]},
#                           'lucky': {'term_freq': 1,
#                                     'tokens': [{'position': 241}]},
#                           'major': {'term_freq': 2,
#                                     'tokens': [{'position': 89},
#                                                {'position': 134}]},
#                           'mar': {'term_freq': 1,
#                                   'tokens': [{'position': 401}]},
#                           'marooned': {'term_freq': 1,
#                                        'tokens': [{'position': 490}]},
#                           'mathematic': {'term_freq': 1,
#                                          'tokens': [{'position': 345}]},
#                           'member': {'term_freq': 2,
#                                      'tokens': [{'position': 356},
#                                                 {'position': 368}]},
#                           'mensa': {'term_freq': 1,
#                                     'tokens': [{'position': 361}]},
#                           'mention': {'term_freq': 1,
#                                       'tokens': [{'position': 310}]},
#                           'more': {'term_freq': 2,
#                                    'tokens': [{'position': 68},
#                                               {'position': 382}]},
#                           'most': {'term_freq': 2,
#                                    'tokens': [{'position': 125},
#                                               {'position': 265}]},
#                           'much': {'term_freq': 2,
#                                    'tokens': [{'position': 188},
#                                               {'position': 263}]},
#                           'mystery': {'term_freq': 2,
#                                       'tokens': [{'position': 257},
#                                                  {'position': 467}]},
#                           'name': {'term_freq': 1,
#                                    'tokens': [{'position': 252}]},
#                           'named': {'term_freq': 1,
#                                     'tokens': [{'position': 411}]},
#                           'nationality': {'term_freq': 2,
#                                           'tokens': [{'position': 300},
#                                                      {'position': 451}]},
#                           'new': {'term_freq': 3,
#                                   'tokens': [{'position': 447},
#                                              {'position': 539},
#                                              {'position': 541}]},
#                           'nightfall': {'term_freq': 1,
#                                         'tokens': [{'position': 216}]},
#                           'nonfiction': {'term_freq': 1,
#                                          'tokens': [{'position': 264}]},
#                           'novel': {'term_freq': 2,
#                                     'tokens': [{'position': 148},
#                                                {'position': 248}]},
#                           'occupation': {'term_freq': 1,
#                                          'tokens': [{'position': 456}]},
#                           'off': {'term_freq': 1,
#                                   'tokens': [{'position': 491}]},
#                           'often': {'term_freq': 1,
#                                     'tokens': [{'position': 298}]},
#                           'one': {'term_freq': 1,
#                                   'tokens': [{'position': 113}]},
#                           'organization': {'term_freq': 1,
#                                            'tokens': [{'position': 371}]},
#                           'other': {'term_freq': 1,
#                                     'tokens': [{'position': 133}]},
#                           'ozimov': {'term_freq': 2,
#                                      'tokens': [{'position': 3},
#                                                 {'position': 28}]},
#                           'paul': {'term_freq': 2,
#                                    'tokens': [{'position': 13},
#                                               {'position': 253}]},
#                           'pen': {'term_freq': 1,
#                                   'tokens': [{'position': 251}]},
#                           'petrovichi': {'term_freq': 1,
#                                          'tokens': [{'position': 528}]},
#                           'phd': {'term_freq': 1,
#                                   'tokens': [{'position': 483}]},
#                           'physic': {'term_freq': 1,
#                                      'tokens': [{'position': 331}]},
#                           'pioneered': {'term_freq': 1,
#                                         'tokens': [{'position': 191}]},
#                           'place': {'term_freq': 4,
#                                     'tokens': [{'position': 424},
#                                                {'position': 444},
#                                                {'position': 524},
#                                                {'position': 535}]},
#                           'planet': {'term_freq': 1,
#                                      'tokens': [{'position': 400}]},
#                           'popular': {'term_freq': 3,
#                                       'tokens': [{'position': 58},
#                                                  {'position': 268},
#                                                  {'position': 471}]},
#                           'possible': {'term_freq': 1,
#                                        'tokens': [{'position': 283}]},
#                           'postcard': {'term_freq': 1,
#                                        'tokens': [{'position': 78}]},
#                           'poul': {'term_freq': 1,
#                                    'tokens': [{'position': 203}]},
#                           'president': {'term_freq': 2,
#                                         'tokens': [{'position': 359},
#                                                    {'position': 386}]},
#                           'previously': {'term_freq': 1,
#                                          'tokens': [{'position': 197}]},
#                           'produced': {'term_freq': 1,
#                                        'tokens': [{'position': 198}]},
#                           'professor': {'term_freq': 2,
#                                         'tokens': [{'position': 41},
#                                                    {'position': 459}]},
#                           'prolific': {'term_freq': 1,
#                                        'tokens': [{'position': 63}]},
#                           'pronunciation': {'term_freq': 1,
#                                             'tokens': [{'position': 316}]},
#                           'proud': {'term_freq': 1,
#                                     'tokens': [{'position': 374}]},
#                           'provide': {'term_freq': 1,
#                                       'tokens': [{'position': 299}]},
#                           'pseudonym': {'term_freq': 2,
#                                         'tokens': [{'position': 14},
#                                                    {'position': 18}]},
#                           'published': {'term_freq': 1,
#                                         'tokens': [{'position': 83}]},
#                           'question': {'term_freq': 1,
#                                        'tokens': [{'position': 291}]},
#                           'reluctantly': {'term_freq': 1,
#                                           'tokens': [{'position': 364}]},
#                           'republic': {'term_freq': 1,
#                                        'tokens': [{'position': 533}]},
#                           'robert': {'term_freq': 2,
#                                      'tokens': [{'position': 103},
#                                                 {'position': 193}]},
#                           'robot': {'term_freq': 2,
#                                     'tokens': [{'position': 143},
#                                                {'position': 176}]},
#                           'robyn': {'term_freq': 1,
#                                     'tokens': [{'position': 439}]},
#                           'russian': {'term_freq': 5,
#                                       'tokens': [{'position': 8},
#                                                  {'position': 11},
#                                                  {'position': 453},
#                                                  {'position': 517},
#                                                  {'position': 529}]},
#                           's.f': {'term_freq': 1,
#                                   'tokens': [{'position': 494}]},
#                           'same': {'term_freq': 1,
#                                    'tokens': [{'position': 157}]},
#                           'school': {'term_freq': 1,
#                                      'tokens': [{'position': 405}]},
#                           'science': {'term_freq': 15,
#                                       'tokens': [{'position': 53},
#                                                  {'position': 59},
#                                                  {'position': 98},
#                                                  {'position': 118},
#                                                  {'position': 214},
#                                                  {'position': 224},
#                                                  {'position': 232},
#                                                  {'position': 246},
#                                                  {'position': 269},
#                                                  {'position': 289},
#                                                  {'position': 325},
#                                                  {'position': 336},
#                                                  {'position': 465},
#                                                  {'position': 472},
#                                                  {'position': 473}]},
#                           'scientific': {'term_freq': 1,
#                                          'tokens': [{'position': 272}]},
#                           'scientist': {'term_freq': 1,
#                                         'tokens': [{'position': 308}]},
#                           'sery': {'term_freq': 6,
#                                    'tokens': [{'position': 131},
#                                               {'position': 135},
#                                               {'position': 140},
#                                               {'position': 144},
#                                               {'position': 163},
#                                               {'position': 243}]},
#                           'set': {'term_freq': 2,
#                                   'tokens': [{'position': 151},
#                                              {'position': 329}]},
#                           "shakespeare'": {'term_freq': 1,
#                                            'tokens': [{'position': 348}]},
#                           'short': {'term_freq': 4,
#                                     'tokens': [{'position': 209},
#                                                {'position': 231},
#                                                {'position': 495},
#                                                {'position': 514}]},
#                           'signature': {'term_freq': 1,
#                                         'tokens': [{'position': 498}]},
#                           'signature.svg': {'term_freq': 1,
#                                             'tokens': [{'position': 502}]},
#                           'simplest': {'term_freq': 1,
#                                        'tokens': [{'position': 295}]},
#                           'smith': {'term_freq': 1,
#                                     'tokens': [{'position': 201}]},
#                           'social': {'term_freq': 1,
#                                      'tokens': [{'position': 213}]},
#                           'socialist': {'term_freq': 1,
#                                         'tokens': [{'position': 532}]},
#                           'some': {'term_freq': 1,
#                                    'tokens': [{'position': 367}]},
#                           'soviet': {'term_freq': 1,
#                                      'tokens': [{'position': 530}]},
#                           'spacer': {'term_freq': 1,
#                                      'tokens': [{'position': 178}]},
#                           'spouse': {'term_freq': 1,
#                                      'tokens': [{'position': 427}]},
#                           'stage': {'term_freq': 1,
#                                     'tokens': [{'position': 296}]},
#                           'starr': {'term_freq': 1,
#                                     'tokens': [{'position': 242}]},
#                           'story': {'term_freq': 5,
#                                     'tokens': [{'position': 179},
#                                                {'position': 187},
#                                                {'position': 210},
#                                                {'position': 234},
#                                                {'position': 496}]},
#                           'subject': {'term_freq': 1,
#                                       'tokens': [{'position': 469}]},
#                           'technical': {'term_freq': 1,
#                                         'tokens': [{'position': 319}]},
#                           'term': {'term_freq': 1,
#                                    'tokens': [{'position': 320}]},
#                           'textbook': {'term_freq': 1,
#                                        'tokens': [{'position': 474}]},
#                           'than': {'term_freq': 1,
#                                    'tokens': [{'position': 69}]},
#                           'those': {'term_freq': 1,
#                                     'tokens': [{'position': 190}]},
#                           'three': {'term_freq': 2,
#                                     'tokens': [{'position': 117},
#                                                {'position': 327}]},
#                           'time': {'term_freq': 3,
#                                    'tokens': [{'position': 237},
#                                               {'position': 286},
#                                               {'position': 355}]},
#                           'took': {'term_freq': 1,
#                                    'tokens': [{'position': 381}]},
#                           'u.': {'term_freq': 2,
#                                  'tokens': [{'position': 449},
#                                             {'position': 543}]},
#                           'understanding': {'term_freq': 1,
#                                             'tokens': [{'position': 330}]},
#                           'unified': {'term_freq': 1,
#                                       'tokens': [{'position': 182}]},
#                           'universe': {'term_freq': 1,
#                                        'tokens': [{'position': 159}]},
#                           'university': {'term_freq': 2,
#                                          'tokens': [{'position': 46},
#                                                     {'position': 482}]},
#                           'using': {'term_freq': 1,
#                                     'tokens': [{'position': 249}]},
#                           'vesta': {'term_freq': 1,
#                                     'tokens': [{'position': 492}]},
#                           'vice': {'term_freq': 1,
#                                    'tokens': [{'position': 358}]},
#                           'volume': {'term_freq': 1,
#                                      'tokens': [{'position': 328}]},
#                           'voted': {'term_freq': 1,
#                                     'tokens': [{'position': 221}]},
#                           'way': {'term_freq': 1,
#                                   'tokens': [{'position': 277}]},
#                           'well': {'term_freq': 3,
#                                    'tokens': [{'position': 261},
#                                               {'position': 312},
#                                               {'position': 340}]},
#                           'when': {'term_freq': 1,
#                                    'tokens': [{'position': 287}]},
#                           'which': {'term_freq': 1,
#                                     'tokens': [{'position': 217}]},
#                           'william': {'term_freq': 1,
#                                       'tokens': [{'position': 347}]},
#                           'work': {'term_freq': 4,
#                                    'tokens': [{'position': 51},
#                                               {'position': 127},
#                                               {'position': 342},
#                                               {'position': 488}]},
#                           'writer': {'term_freq': 4,
#                                      'tokens': [{'position': 120},
#                                                 {'position': 226},
#                                                 {'position': 458},
#                                                 {'position': 520}]},
#                           'writing': {'term_freq': 1,
#                                       'tokens': [{'position': 349}]},
#                           'wrote': {'term_freq': 5,
#                                     'tokens': [{'position': 65},
#                                                {'position': 96},
#                                                {'position': 206},
#                                                {'position': 239},
#                                                {'position': 256}]},
#                           'york': {'term_freq': 3,
#                                    'tokens': [{'position': 448},
#                                               {'position': 540},
#                                               {'position': 542}]},
#                           'yudovich': {'term_freq': 2,
#                                        'tokens': [{'position': 2},
#                                                   {'position': 27}]},
#                           'ˈaIzik': {'term_freq': 1,
#                                      'tokens': [{'position': 23}]},
#                           'ˈaezimɒv': {'term_freq': 1,
#                                        'tokens': [{'position': 24}]},
#                           'азимов': {'term_freq': 1,
#                                      'tokens': [{'position': 10}]},
#                           'айзек': {'term_freq': 1,
#                                     'tokens': [{'position': 9}]},
#                           'исаак': {'term_freq': 1,
#                                     'tokens': [{'position': 6}]},
#                           'озимов': {'term_freq': 1,
#                                      'tokens': [{'position': 7}]}}},
#  'catch_all': {'field_statistics': {'doc_count': 4670331,
#                                     'sum_doc_freq': 181848260,
#                                     'sum_ttf': 242142938},
#                'terms': {'01': {'term_freq': 3,
#                                 'tokens': [{'position': 68},
#                                            {'position': 90},
#                                            {'position': 121}]},
#                          '02': {'term_freq': 3,
#                                 'tokens': [{'position': 69},
#                                            {'position': 91},
#                                            {'position': 122}]},
#                          '04': {'term_freq': 6,
#                                 'tokens': [{'position': 71},
#                                            {'position': 83},
#                                            {'position': 85},
#                                            {'position': 114},
#                                            {'position': 116},
#                                            {'position': 124}]},
#                          '06': {'term_freq': 4,
#                                 'tokens': [{'position': 72},
#                                            {'position': 86},
#                                            {'position': 117},
#                                            {'position': 125}]},
#                          '10': {'term_freq': 2,
#                                 'tokens': [{'position': 82},
#                                            {'position': 113}]},
#                          '1919': {'term_freq': 1, 'tokens': [{'position': 81}]},
#                          '1920': {'term_freq': 5,
#                                   'tokens': [{'position': 11},
#                                              {'position': 67},
#                                              {'position': 89},
#                                              {'position': 92},
#                                              {'position': 120}]},
#                          '1939': {'term_freq': 2,
#                                   'tokens': [{'position': 87},
#                                              {'position': 118}]},
#                          '1992': {'term_freq': 7,
#                                   'tokens': [{'position': 14},
#                                              {'position': 70},
#                                              {'position': 84},
#                                              {'position': 88},
#                                              {'position': 99},
#                                              {'position': 115},
#                                              {'position': 123}]},
#                          '2': {'term_freq': 1, 'tokens': [{'position': 10}]},
#                          '500': {'term_freq': 1, 'tokens': [{'position': 49}]},
#                          '6': {'term_freq': 1, 'tokens': [{'position': 13}]},
#                          '68': {'term_freq': 1, 'tokens': [{'position': 119}]},
#                          '90,000': {'term_freq': 1,
#                                     'tokens': [{'position': 54}]},
#                          'agent': {'term_freq': 2,
#                                    'tokens': [{'position': 110},
#                                               {'position': 112}]},
#                          'american': {'term_freq': 3,
#                                       'tokens': [{'position': 17},
#                                                  {'position': 62},
#                                                  {'position': 95}]},
#                          'april': {'term_freq': 1,
#                                    'tokens': [{'position': 12}]},
#                          'asimov': {'term_freq': 2,
#                                     'tokens': [{'position': 1},
#                                                {'position': 40}]},
#                          'author': {'term_freq': 1,
#                                     'tokens': [{'position': 18}]},
#                          'best': {'term_freq': 1, 'tokens': [{'position': 26}]},
#                          'biochemist': {'term_freq': 2,
#                                         'tokens': [{'position': 65},
#                                                    {'position': 98}]},
#                          'biochemistry': {'term_freq': 1,
#                                           'tokens': [{'position': 22}]},
#                          'book': {'term_freq': 2,
#                                   'tokens': [{'position': 39},
#                                              {'position': 50}]},
#                          'born': {'term_freq': 3,
#                                   'tokens': [{'position': 4},
#                                              {'position': 61},
#                                              {'position': 94}]},
#                          'boston': {'term_freq': 1,
#                                     'tokens': [{'position': 24}]},
#                          'circa': {'term_freq': 1, 'tokens': [{'position': 8}]},
#                          'criticism': {'term_freq': 1,
#                                        'tokens': [{'position': 79}]},
#                          'dul.owl': {'term_freq': 2,
#                                      'tokens': [{'position': 108},
#                                                 {'position': 111}]},
#                          'edited': {'term_freq': 1,
#                                     'tokens': [{'position': 46}]},
#                          'estimated': {'term_freq': 1,
#                                        'tokens': [{'position': 53}]},
#                          'fiction': {'term_freq': 1,
#                                      'tokens': [{'position': 33}]},
#                          'hi': {'term_freq': 2,
#                                 'tokens': [{'position': 29}, {'position': 36}]},
#                          'isaac': {'term_freq': 1, 'tokens': [{'position': 0}]},
#                          'isaak': {'term_freq': 1, 'tokens': [{'position': 5}]},
#                          'january': {'term_freq': 1,
#                                      'tokens': [{'position': 9}]},
#                          'known': {'term_freq': 1,
#                                    'tokens': [{'position': 27}]},
#                          'letter': {'term_freq': 1,
#                                     'tokens': [{'position': 55}]},
#                          'literary': {'term_freq': 1,
#                                       'tokens': [{'position': 78}]},
#                          'more': {'term_freq': 1, 'tokens': [{'position': 47}]},
#                          'naturalperson': {'term_freq': 1,
#                                            'tokens': [{'position': 109}]},
#                          'owl': {'term_freq': 1, 'tokens': [{'position': 104}]},
#                          'ozimov': {'term_freq': 1,
#                                     'tokens': [{'position': 7}]},
#                          'person': {'term_freq': 4,
#                                     'tokens': [{'position': 59},
#                                                {'position': 101},
#                                                {'position': 103},
#                                                {'position': 106}]},
#                          'popular': {'term_freq': 2,
#                                      'tokens': [{'position': 37},
#                                                 {'position': 73}]},
#                          'postcard': {'term_freq': 1,
#                                       'tokens': [{'position': 57}]},
#                          'professor': {'term_freq': 1,
#                                        'tokens': [{'position': 20}]},
#                          'prolific': {'term_freq': 1,
#                                       'tokens': [{'position': 42}]},
#                          'q215627': {'term_freq': 1,
#                                      'tokens': [{'position': 107}]},
#                          'q36180': {'term_freq': 1,
#                                     'tokens': [{'position': 100}]},
#                          'q5': {'term_freq': 1, 'tokens': [{'position': 102}]},
#                          'russian': {'term_freq': 2,
#                                      'tokens': [{'position': 60},
#                                                 {'position': 93}]},
#                          'science': {'term_freq': 3,
#                                      'tokens': [{'position': 32},
#                                                 {'position': 38},
# ...
#                                                          {'position': 4842},
#                                                          {'position': 4845},
#                                                          {'position': 4848},
#                                                          {'position': 4854},
#                                                          {'position': 4857},
#                                                          {'position': 4860},
#                                                          {'position': 4863},
#                                                          {'position': 4866},
#                                                          {'position': 4869},
#                                                          {'position': 4873},
#                                                          {'position': 4875},
#                                                          {'position': 4879},
#                                                          {'position': 4881},
#                                                          {'position': 4884},
#                                                          {'position': 4887},
#                                                          {'position': 4890},
#                                                          {'position': 4893},
#                                                          {'position': 4896},
#                                                          {'position': 4899},
#                                                          {'position': 4902},
#                                                          {'position': 4905},
#                                                          {'position': 4908},
#                                                          {'position': 4911},
#                                                          {'position': 4914},
#                                                          {'position': 4917},
#                                                          {'position': 4920},
#                                                          {'position': 4923},
#                                                          {'position': 4926},
#                                                          {'position': 4929},
#                                                          {'position': 4932},
#                                                          {'position': 4935},
#                                                          {'position': 4940},
#                                                          {'position': 4943},
#                                                          {'position': 4946},
#                                                          {'position': 4949},
#                                                          {'position': 4952},
#                                                          {'position': 4955},
#                                                          {'position': 4958},
#                                                          {'position': 4961},
#                                                          {'position': 4964},
#                                                          {'position': 4967},
#                                                          {'position': 4970},
#                                                          {'position': 4973},
#                                                          {'position': 4976},
#                                                          {'position': 4979},
#                                                          {'position': 4982},
#                                                          {'position': 4985},
#                                                          {'position': 4988},
#                                                          {'position': 4991},
#                                                          {'position': 4994},
#                                                          {'position': 4997},
#                                                          {'position': 5000},
#                                                          {'position': 5003},
#                                                          {'position': 5006},
#                                                          {'position': 5009},
#                                                          {'position': 5012},
#                                                          {'position': 5015},
#                                                          {'position': 5018},
#                                                          {'position': 5021},
#                                                          {'position': 5025},
#                                                          {'position': 5029},
#                                                          {'position': 5032},
#                                                          {'position': 5035},
#                                                          {'position': 5038},
#                                                          {'position': 5041},
#                                                          {'position': 5048},
#                                                          {'position': 5051},
#                                                          {'position': 5054},
#                                                          {'position': 5057},
#                                                          {'position': 5060},
#                                                          {'position': 5063},
#                                                          {'position': 5066},
#                                                          {'position': 5069},
#                                                          {'position': 5072},
#                                                          {'position': 5075},
#                                                          {'position': 5078},
#                                                          {'position': 5081},
#                                                          {'position': 5086},
#                                                          {'position': 5089},
#                                                          {'position': 5092},
#                                                          {'position': 5095},
#                                                          {'position': 5098},
#                                                          {'position': 5101},
#                                                          {'position': 5104},
#                                                          {'position': 5107},
#                                                          {'position': 5110},
#                                                          {'position': 5113},
#                                                          {'position': 5116},
#                                                          {'position': 5119},
#                                                          {'position': 5122},
#                                                          {'position': 5125},
#                                                          {'position': 5128},
#                                                          {'position': 5131},
#                                                          {'position': 5134},
#                                                          {'position': 5137},
#                                                          {'position': 5140},
#                                                          {'position': 5143},
#                                                          {'position': 5146},
#                                                          {'position': 5149},
#                                                          {'position': 5152},
#                                                          {'position': 5155},
#                                                          {'position': 5158},
#                                                          {'position': 5161},
#                                                          {'position': 5164},
#                                                          {'position': 5167},
#                                                          {'position': 5170},
#                                                          {'position': 5173},
#                                                          {'position': 5177},
#                                                          {'position': 5179},
#                                                          {'position': 5182},
#                                                          {'position': 5186},
#                                                          {'position': 5188},
#                                                          {'position': 5191},
#                                                          {'position': 5194},
#                                                          {'position': 5197},
#                                                          {'position': 5200},
#                                                          {'position': 5203},
#                                                          {'position': 5206},
#                                                          {'position': 5209},
#                                                          {'position': 5214},
#                                                          {'position': 5217}]},
#                                     'isaacasimov': {'term_freq': 1,
#                                                     'tokens': [{'position': 133}]},
#                                     'isaak': {'term_freq': 2,
#                                               'tokens': [{'position': 0},
#                                                          {'position': 6}]},
#                                     'isac': {'term_freq': 1,
#                                              'tokens': [{'position': 69}]},
#                                     'isacc': {'term_freq': 1,
#                                               'tokens': [{'position': 84}]},
#                                     'issac': {'term_freq': 4,
#                                               'tokens': [{'position': 100},
#                                                          {'position': 109},
#                                                          {'position': 130},
#                                                          {'position': 3899}]},
#                                     'izaak': {'term_freq': 1,
#                                               'tokens': [{'position': 3}]},
#                                     'law': {'term_freq': 1,
#                                             'tokens': [{'position': 3650}]},
#                                     'list': {'term_freq': 2,
#                                              'tokens': [{'position': 34},
#                                                         {'position': 62}]},
#                                     'm': {'term_freq': 1,
#                                           'tokens': [{'position': 642}]},
#                                     'manya': {'term_freq': 1,
#                                               'tokens': [{'position': 53}]},
#                                     'marcia': {'term_freq': 1,
#                                                'tokens': [{'position': 50}]},
#                                     'mauve': {'term_freq': 1,
#                                               'tokens': [{'position': 5046}]},
#                                     'move': {'term_freq': 1,
#                                              'tokens': [{'position': 647}]},
#                                     'obey': {'term_freq': 1,
#                                              'tokens': [{'position': 3647}]},
#                                     'other': {'term_freq': 2,
#                                               'tokens': [{'position': 1871},
#                                                          {'position': 1876}]},
#                                     'own': {'term_freq': 1,
#                                             'tokens': [{'position': 3642}]},
#                                     'ozimov': {'term_freq': 3,
#                                                'tokens': [{'position': 1},
#                                                           {'position': 4},
#                                                           {'position': 8}]},
#                                     'paternalistic': {'term_freq': 1,
#                                                       'tokens': [{'position': 4417}]},
#                                     'paul': {'term_freq': 1,
#                                              'tokens': [{'position': 3973}]},
#                                     'robot': {'term_freq': 1,
#                                               'tokens': [{'position': 3645}]},
#                                     's': {'term_freq': 2,
#                                           'tokens': [{'position': 639},
#                                                      {'position': 641}]},
#                                     'season': {'term_freq': 2,
#                                                'tokens': [{'position': 92},
#                                                           {'position': 4280}]},
#                                     'seasonal': {'term_freq': 1,
#                                                  'tokens': [{'position': 88}]},
#                                     'selected': {'term_freq': 11,
#                                                  'tokens': [{'position': 259},
#                                                             {'position': 687},
#                                                             {'position': 692},
#                                                             {'position': 796},
#                                                             {'position': 905},
#                                                             {'position': 981},
#                                                             {'position': 986},
#                                                             {'position': 1156},
#                                                             {'position': 1640},
#                                                             {'position': 1887},
#                                                             {'position': 3750}]},
#                                     'sery': {'term_freq': 1,
#                                              'tokens': [{'position': 2565}]},
#                                     'term': {'term_freq': 1,
#                                              'tokens': [{'position': 3643}]},
#                                     'three': {'term_freq': 1,
#                                               'tokens': [{'position': 3649}]},
#                                     'v': {'term_freq': 1,
#                                           'tokens': [{'position': 643}]},
#                                     'which': {'term_freq': 1,
#                                               'tokens': [{'position': 3646}]},
#                                     'work': {'term_freq': 4,
#                                              'tokens': [{'position': 32},
#                                                         {'position': 38},
#                                                         {'position': 57},
#                                                         {'position': 60}]},
#                                     'world': {'term_freq': 3,
#                                               'tokens': [{'position': 87},
#                                                          {'position': 91},
#                                                          {'position': 4279}]},
#                                     'writing': {'term_freq': 2,
#                                                 'tokens': [{'position': 1872},
#                                                            {'position': 1877}]},
#                                     'yudovich': {'term_freq': 1,
#                                                  'tokens': [{'position': 7}]}}}}

# %% [markdown]
# ## Computing field lengths

# %%
collection_stats = {}

for field, stats in tv.items():
    collection_stats[field] = stats['field_statistics']
    
with open('data/collection_stats.json', 'w') as f:
    json.dump(collection_stats, f, indent=4)

# %%
collection_stats
# Out:
# {'attributes': {'sum_doc_freq': 285985189,
#   'doc_count': 4673761,
#   'sum_ttf': 408590200},
#  'related_entity_names': {'sum_doc_freq': 253984319,
#   'doc_count': 4672196,
#   'sum_ttf': 484036251},
#  'catch_all': {'sum_doc_freq': 181848260,
#   'doc_count': 4670331,
#   'sum_ttf': 242142938},
#  'categories': {'sum_doc_freq': 48566914,
#   'doc_count': 4623214,
#   'sum_ttf': 67749741},
#  'names': {'sum_doc_freq': 15904769,
#   'doc_count': 4673671,
#   'sum_ttf': 39369886},
#  'similar_entity_names': {'sum_doc_freq': 21662487,
#   'doc_count': 4496193,
#   'sum_ttf': 256472073},
#  'related_entity_uri': {'sum_doc_freq': 157668925,
#   'doc_count': 4672196,
#   'sum_ttf': 194688711}}

# %% [markdown]
# ## Modifying the default scoring

# %%
es.indices.close(index=INDEX_NAME)
# Out:
# {'acknowledged': True,
#  'shards_acknowledged': True,
#  'indices': {'collection_v2': {'closed': True}}}

# %%
body = {
    "similarity": {
        "default": {
            "type": "DFI",
            "independence_measure": "standardized"
        }
    }
}

es.indices.put_settings(index=INDEX_NAME, body=body)
# Out:
# {'acknowledged': True}

# %%
es.indices.open(index=INDEX_NAME)
# Out:
# {'acknowledged': True, 'shards_acknowledged': True}
